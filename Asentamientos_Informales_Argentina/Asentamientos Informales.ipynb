# %% [markdown]
# Estudio
# # INFORME SOBRE ASENTAMIENTOS INFORMALES EN ARGENTINA

# %%
# Comenzamos importando las librerias a utilizar por el momento.

import numpy as np   # Importamos librerias de calculo
import pandas as pd  # Importamos librerias de uso de tablas o los dataframes
import seaborn as sns # Importamos librerias de graficos
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Ubicar el dataset, cargarlo y mostrarlo.
url='https://raw.githubusercontent.com/NestorDiazDataSC/Analisis_de_Datos/main/Asentamientos_Informales_Argentina/Dataset%20Relevamiento.csv'

df= pd.read_csv(url)
df
# Out:
#              ID                        provincia  \
# 0     TE_000001                     BUENOS AIRES
# 1     TE_000008                          NEUQUÉN
# 2     TE_000009                          NEUQUÉN
# 3     TE_000013                          NEUQUÉN
# 4     TE_000020                          NEUQUÉN
# ...         ...                              ...
# 2592  TE_004332                     BUENOS AIRES
# 2593  TE_004333                     BUENOS AIRES
# 2594  TE_004334                     BUENOS AIRES
# 2595  TE_004335                     BUENOS AIRES
# 2596  TE_004337  CIUDAD AUTÓNOMA DE BUENOS AIRES
#
#                          departamento                  localidad  \
# 0                               TIGRE                    CHASICÓ
# 1                         CONFLUENCIA                    NEUQUÉN
# 2                         CONFLUENCIA                    NEUQUÉN
# 3                         CONFLUENCIA                    NEUQUÉN
# 4                         CONFLUENCIA                    NEUQUÉN
# ...                               ...                        ...
# 2592                      SAN NICOLAS                   RÍO TALA
# 2593                        ARRECIFES  ARRECIFES (CABECERA PDO.)
# 2594                        ARRECIFES  ARRECIFES (CABECERA PDO.)
# 2595                          BRAGADO    BRAGADO (CABECERA PDO.)
# 2596  CIUDAD AUTÓNOMA DE BUENOS AIRES                   COMUNA 4
#
#          nombre_barrio      otros_nombres_barrio tipo_de_barrio  \
# 0          el ahorcado                       NaN          VILLA
# 1      nueva esperanza  dentro de villa ceferino   ASENTAMIENTO
# 2       loteo social 1                toma norte   ASENTAMIENTO
# 3      toma alto godoy                  no tiene   ASENTAMIENTO
# 4         Auka Mahuida                       NaN   ASENTAMIENTO
# ...                ...                       ...            ...
# 2592        12/03/2016                       NaN   ASENTAMIENTO
# 2593           lavalle                       NaN   ASENTAMIENTO
# 2594  tucan y escalada                       NaN   ASENTAMIENTO
# 2595    hermanos islas                       NaN   ASENTAMIENTO
# 2596         Olavarría                       NaN            NaN
#
#       cantidad_de_familias  anio_creo_barrio  \
# 0                      190            1975.0
# 1                       30            1990.0
# 2                       30            2007.0
# 3                       70            1990.0
# 4                      150            2004.0
# ...                    ...               ...
# 2592                    20               NaN
# 2593                    25               NaN
# 2594                    30               NaN
# 2595                    10               NaN
# 2596                   100            1999.0
#
#                                                     luz  ... alcantarillado  \
# 0     RED PÚBLICA CON MEDIDORES DOMICILIARIOS. (CADA...  ...             NO
# 1     CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...  ...             NO
# 2     CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...  ...             NO
# 3     CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...  ...             NO
# 4     CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...  ...             NO
# ...                                                 ...  ...            ...
# 2592  CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...  ...            NaN
# 2593  CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...  ...            NaN
# 2594  RED PÚBLICA CON MEDIDORES DOMICILIARIOS. (CADA...  ...            NaN
# 2595  CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...  ...            NaN
# 2596                                                NaN  ...            NaN
#
#      asfalto                     alumbrado  \
# 0         NO  SI, PROVISTOS POR EL ESTADO.
# 1         NO                            NO
# 2         NO                            NO
# 3         NO  SI, PROVISTOS POR EL ESTADO.
# 4         NO                            NO
# ...      ...                           ...
# 2592     NaN                           NaN
# 2593     NaN                           NaN
# 2594     NaN                           NaN
# 2595     NaN                           NaN
# 2596     NaN                           NaN
#
#                                 recoleccion_de_residuos  \
# 0     SI, DE MANERA FORMAL. (EL CAMIÓN INGRESA AL BA...
# 1                                                    NO
# 2                                                    NO
# 3     SI, DE MANERA FORMAL. (EL CAMIÓN INGRESA AL BA...
# 4                                                    NO
# ...                                                 ...
# 2592                                                NaN
# 2593                                                NaN
# 2594                                                NaN
# 2595                                                NaN
# 2596                                                NaN
#
#      organizaciones_externas        mayores_problemas_barrio1  \
# 0                         NO             DROGA/ALCOHOL/TABACO
# 1                         SÍ  FALTA DE ACCESO A LOS SERVICIOS
# 2                         NO         INSEGURIDAD/DELINCUENCIA
# 3                         NO             DROGA/ALCOHOL/TABACO
# 4                         NO                             OTRO
# ...                      ...                              ...
# 2592                     NaN                              NaN
# 2593                     NaN                              NaN
# 2594                     NaN                              NaN
# 2595                     NaN                              NaN
# 2596                     NaN                              NaN
#
#                 cosas_que_mas_le_gustan1  \
# 0                                   OTRO
# 1     UNIÓN Y FAMILIARIDAD ENTRE VECINOS
# 2     UNIÓN Y FAMILIARIDAD ENTRE VECINOS
# 3                           TRANQUILIDAD
# 4     EL PROGRESO PERCIBIDO EN EL BARRIO
# ...                                  ...
# 2592                                 NaN
# 2593                                 NaN
# 2594                                 NaN
# 2595                                 NaN
# 2596                                 NaN
#
#                                                poligono  \
# 0     -58.59945100000001,-34.405688 -58.600438,-34.4...
# 1     -68.09599718832222,-38.94101958422372 -68.0956...
# 2     -68.11663400000001,-38.929042 -68.117119,-38.9...
# 3     -68.11655008297473,-38.93412118363295 -68.1163...
# 4     -68.07649248356904,-38.9414112252755 -68.07682...
# ...                                                 ...
# 2592                                                  0
# 2593  -60.11637086009928,-34.06829519373805 -60.1161...
# 2594  -60.1207924,-34.0649966 -60.1214147,-34.065885...
# 2595  -60.4987211494109,-35.10716108684236 -60.49969...
# 2596                                                NaN
#
#                        IDENTIFICAR  anio
# 0        CUMPLE CON LA DEFINICIÓN   2016
# 1        CUMPLE CON LA DEFINICIÓN   2016
# 2        CUMPLE CON LA DEFINICIÓN   2016
# 3        CUMPLE CON LA DEFINICIÓN   2016
# 4        CUMPLE CON LA DEFINICIÓN   2016
# ...                            ...   ...
# 2592     CUMPLE CON LA DEFINICIÓN   2016
# 2593     CUMPLE CON LA DEFINICIÓN   2016
# 2594     CUMPLE CON LA DEFINICIÓN   2016
# 2595     CUMPLE CON LA DEFINICIÓN   2016
# 2596  NO CUMPLE CON LA DEFINICIÓN   2016
#
# [2597 rows x 47 columns]

# %%
df.describe () # Muestra estadistica basica del dataframe
# Out:
#        cantidad_de_familias  anio_creo_barrio    anio
# count           2597.000000       2461.000000  2597.0
# mean             266.507894       1987.847623  2016.0
# std              630.088406         21.551054     0.0
# min                3.000000       1888.000000  2016.0
# 25%               40.000000       1975.000000  2016.0
# 50%              100.000000       1991.000000  2016.0
# 75%              270.000000       2006.000000  2016.0
# max            13000.000000       2015.000000  2016.0

# %% [markdown]
# A partir de aqui, se comienza a estudiar como esta compuesta la base de datos

# %%
df.describe (include = "all") # Muestra estadisticas de valores que no son numericos
# Out:
#                ID     provincia departamento        localidad nombre_barrio  \
# count        2597          2597         2597             2589          2596
# unique       2597            11          113              357          2360
# top     TE_000001  BUENOS AIRES      CAPITAL  CÓRDOBA CAPITAL  San Cayetano
# freq            1          1440          400              126            12
# mean          NaN           NaN          NaN              NaN           NaN
# std           NaN           NaN          NaN              NaN           NaN
# min           NaN           NaN          NaN              NaN           NaN
# 25%           NaN           NaN          NaN              NaN           NaN
# 50%           NaN           NaN          NaN              NaN           NaN
# 75%           NaN           NaN          NaN              NaN           NaN
# max           NaN           NaN          NaN              NaN           NaN
#
#        otros_nombres_barrio tipo_de_barrio  cantidad_de_familias  \
# count                   662           2288           2597.000000
# unique                  620              6                   NaN
# top                       -   ASENTAMIENTO                   NaN
# freq                     10           1703                   NaN
# mean                    NaN            NaN            266.507894
# std                     NaN            NaN            630.088406
# min                     NaN            NaN              3.000000
# 25%                     NaN            NaN             40.000000
# 50%                     NaN            NaN            100.000000
# 75%                     NaN            NaN            270.000000
# max                     NaN            NaN          13000.000000
#
#         anio_creo_barrio                                                luz  \
# count        2461.000000                                               2574
# unique               NaN                                                  6
# top                  NaN  CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...
# freq                 NaN                                               1575
# mean         1987.847623                                                NaN
# std            21.551054                                                NaN
# min          1888.000000                                                NaN
# 25%          1975.000000                                                NaN
# 50%          1991.000000                                                NaN
# 75%          2006.000000                                                NaN
# max          2015.000000                                                NaN
#
#         ... alcantarillado asfalto                     alumbrado  \
# count   ...           2150    2141                          2153
# unique  ...              5       4                             5
# top     ...             NO      NO  SI, PROVISTOS POR EL ESTADO.
# freq    ...           1575    1457                          1165
# mean    ...            NaN     NaN                           NaN
# std     ...            NaN     NaN                           NaN
# min     ...            NaN     NaN                           NaN
# 25%     ...            NaN     NaN                           NaN
# 50%     ...            NaN     NaN                           NaN
# 75%     ...            NaN     NaN                           NaN
# max     ...            NaN     NaN                           NaN
#
#                                   recoleccion_de_residuos  \
# count                                                2156
# unique                                                  4
# top     SI, DE MANERA FORMAL. (EL CAMIÓN INGRESA AL BA...
# freq                                                 1340
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        organizaciones_externas        mayores_problemas_barrio1  \
# count                     2130                             2140
# unique                       5                               10
# top                         NO  FALTA DE ACCESO A LOS SERVICIOS
# freq                      1536                              703
# mean                       NaN                              NaN
# std                        NaN                              NaN
# min                        NaN                              NaN
# 25%                        NaN                              NaN
# 50%                        NaN                              NaN
# 75%                        NaN                              NaN
# max                        NaN                              NaN
#
#        cosas_que_mas_le_gustan1 poligono                IDENTIFICAR    anio
# count                      2121     2568                       2597  2597.0
# unique                        9     2564                          3     NaN
# top                TRANQUILIDAD        0  CUMPLE CON LA DEFINICIÓN      NaN
# freq                        984        5                       2438     NaN
# mean                        NaN      NaN                        NaN  2016.0
# std                         NaN      NaN                        NaN     0.0
# min                         NaN      NaN                        NaN  2016.0
# 25%                         NaN      NaN                        NaN  2016.0
# 50%                         NaN      NaN                        NaN  2016.0
# 75%                         NaN      NaN                        NaN  2016.0
# max                         NaN      NaN                        NaN  2016.0
#
# [11 rows x 47 columns]

# %%
df.info()   # Muestra que tipo de variables hay en el dataframe mas otra información adicional
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2597 entries, 0 to 2596
# Data columns (total 47 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         2597 non-null   object
#  1   provincia                  2597 non-null   object
#  2   departamento               2597 non-null   object
#  3   localidad                  2589 non-null   object
#  4   nombre_barrio              2596 non-null   object
#  5   otros_nombres_barrio       662 non-null    object
#  6   tipo_de_barrio             2288 non-null   object
#  7   cantidad_de_familias       2597 non-null   int64
#  8   anio_creo_barrio           2461 non-null   float64
#  9   luz                        2574 non-null   object
#  10  excretas                   2574 non-null   object
#  11  agua                       2438 non-null   object
#  12  energia_calefaccion        2149 non-null   object
#  13  energia_cocinar            2143 non-null   object
#  14  emergencias_policia        2148 non-null   object
#  15  emergencias_bomberos       2011 non-null   object
#  16  emergencias_ambulancia     2036 non-null   object
#  17  plantacion_forestal        2061 non-null   object
#  18  ribera_rio                 2100 non-null   object
#  19  pendiente                  2068 non-null   object
#  20  basural                    2050 non-null   object
#  21  torres_de_alta_tension     2067 non-null   object
#  22  linea_de_tren              2074 non-null   object
#  23  camino_de_alto_trafico     2076 non-null   object
#  24  desechos_industriales      2062 non-null   object
#  25  actividad_agropecuaria     2061 non-null   object
#  26  relleno_sanitario          2065 non-null   object
#  27  inundaciones               1332 non-null   object
#  28  jardin_de_infantes         2145 non-null   object
#  29  escuela_primaria           2142 non-null   object
#  30  escuela_secundaria         2145 non-null   object
#  31  hospital                   2141 non-null   object
#  32  sala_medica                2140 non-null   object
#  33  comisaria                  2139 non-null   object
#  34  parada_transporte_publico  2126 non-null   object
#  35  plaza                      2141 non-null   object
#  36  centro_de_deportes         2132 non-null   object
#  37  alcantarillado             2150 non-null   object
#  38  asfalto                    2141 non-null   object
#  39  alumbrado                  2153 non-null   object
#  40  recoleccion_de_residuos    2156 non-null   object
#  41  organizaciones_externas    2130 non-null   object
#  42  mayores_problemas_barrio1  2140 non-null   object
#  43  cosas_que_mas_le_gustan1   2121 non-null   object
#  44  poligono                   2568 non-null   object
#  45  IDENTIFICAR                2597 non-null   object
#  46  anio                       2597 non-null   int64
# dtypes: float64(1), int64(2), object(44)
# memory usage: 953.7+ KB

# %%
df.shape # Primer valor la cantidad de filas, segundo valor la cantidad de columnas que tiene el DF.
# Out:
# (2597, 47)

# %%
df.isnull().sum() # Para ver la cantidad de valores nulos de cada columna
# Out:
# ID                              0
# provincia                       0
# departamento                    0
# localidad                       8
# nombre_barrio                   1
# otros_nombres_barrio         1935
# tipo_de_barrio                309
# cantidad_de_familias            0
# anio_creo_barrio              136
# luz                            23
# excretas                       23
# agua                          159
# energia_calefaccion           448
# energia_cocinar               454
# emergencias_policia           449
# emergencias_bomberos          586
# emergencias_ambulancia        561
# plantacion_forestal           536
# ribera_rio                    497
# pendiente                     529
# basural                       547
# torres_de_alta_tension        530
# linea_de_tren                 523
# camino_de_alto_trafico        521
# desechos_industriales         535
# actividad_agropecuaria        536
# relleno_sanitario             532
# inundaciones                 1265
# jardin_de_infantes            452
# escuela_primaria              455
# escuela_secundaria            452
# hospital                      456
# sala_medica                   457
# comisaria                     458
# parada_transporte_publico     471
# plaza                         456
# centro_de_deportes            465
# alcantarillado                447
# asfalto                       456
# alumbrado                     444
# recoleccion_de_residuos       441
# organizaciones_externas       467
# mayores_problemas_barrio1     457
# cosas_que_mas_le_gustan1      476
# poligono                       29
# IDENTIFICAR                     0
# anio                            0
# dtype: int64

# %% [markdown]
# Luego de conocer como esta compuesto el DF. se comienza a trabajar en el mismo para llegar a tener una base mas util para analizar.

# %%
df.drop(['otros_nombres_barrio', 'IDENTIFICAR', 'cosas_que_mas_le_gustan1'], axis = 'columns', inplace=True)
# Eliminamos columnas que no voy a utilizar en el analisis porque no son relevantes o no tienen datos significativos para analizar.

# inplace=True la eliminación de valores se hace directamente en el dataframe original.

# %%
# Hay ciertos lugares o valores en el dataframe que no contiene valor o son NAN, entonces para no tener que anular una fila por no tener
# disponible esos valores, va a ser segun que datos (NAN) tenga la columna, los transformo en un dato mas significativo para el analisis

df["tipo_de_barrio"].fillna("VILLA", inplace = True) # Con esto relleno el NAN con el valor VILLA. El inplace=True modifica el dataset original
df["nombre_barrio"].fillna("Otro", inplace = True)
df["pendiente"].fillna("Plano", inplace = True)
df["anio_creo_barrio"].fillna("No sabe", inplace = True)
df["localidad"].fillna("Caba", inplace = True)
df["inundaciones"].fillna("No tuvo", inplace = True)
df["basural"].fillna("No tiene", inplace = True)
df["actividad_agropecuaria"].fillna("No tiene", inplace = True)
df["emergencias_ambulancia"].fillna("No tiene", inplace = True)
df["agua"].fillna("No tiene", inplace = True)
df["relleno_sanitario"].fillna("No tiene", inplace = True)
df["camino_de_alto_trafico"].fillna("No tiene", inplace = True)
df["desechos_industriales"].fillna("No sabe", inplace = True)
df["plantacion_forestal"].fillna("No sabe", inplace = True)
df["sala_medica"].fillna("No tiene", inplace = True)
df["emergencias_bomberos"].fillna("No tiene", inplace = True)
df["ribera_rio"].fillna("No tiene", inplace = True)
df["comisaria"].fillna("No tiene", inplace = True)
df["torres_de_alta_tension"].fillna("No tiene", inplace = True)
df["linea_de_tren"].fillna("No tiene", inplace = True)
df["organizaciones_externas"].fillna("No tiene", inplace = True)

# %%
df.isnull().sum() # Volvemos a consultar los valores nulos y vemos que se reducen a 0 en muchas de las columnas.
# Out:
# ID                             0
# provincia                      0
# departamento                   0
# localidad                      0
# nombre_barrio                  0
# tipo_de_barrio                 0
# cantidad_de_familias           0
# anio_creo_barrio               0
# luz                           23
# excretas                      23
# agua                           0
# energia_calefaccion          448
# energia_cocinar              454
# emergencias_policia          449
# emergencias_bomberos           0
# emergencias_ambulancia         0
# plantacion_forestal            0
# ribera_rio                     0
# pendiente                      0
# basural                        0
# torres_de_alta_tension         0
# linea_de_tren                  0
# camino_de_alto_trafico         0
# desechos_industriales          0
# actividad_agropecuaria         0
# relleno_sanitario              0
# inundaciones                   0
# jardin_de_infantes           452
# escuela_primaria             455
# escuela_secundaria           452
# hospital                     456
# sala_medica                    0
# comisaria                      0
# parada_transporte_publico    471
# plaza                        456
# centro_de_deportes           465
# alcantarillado               447
# asfalto                      456
# alumbrado                    444
# recoleccion_de_residuos      441
# organizaciones_externas        0
# mayores_problemas_barrio1    457
# poligono                      29
# anio                           0
# dtype: int64

# %%
df.info()   # Volvemos a pasar el codigo para controlar los cambios en el DF
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2597 entries, 0 to 2596
# Data columns (total 44 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         2597 non-null   object
#  1   provincia                  2597 non-null   object
#  2   departamento               2597 non-null   object
#  3   localidad                  2597 non-null   object
#  4   nombre_barrio              2597 non-null   object
#  5   tipo_de_barrio             2597 non-null   object
#  6   cantidad_de_familias       2597 non-null   int64
#  7   anio_creo_barrio           2597 non-null   object
#  8   luz                        2574 non-null   object
#  9   excretas                   2574 non-null   object
#  10  agua                       2597 non-null   object
#  11  energia_calefaccion        2149 non-null   object
#  12  energia_cocinar            2143 non-null   object
#  13  emergencias_policia        2148 non-null   object
#  14  emergencias_bomberos       2597 non-null   object
#  15  emergencias_ambulancia     2597 non-null   object
#  16  plantacion_forestal        2597 non-null   object
#  17  ribera_rio                 2597 non-null   object
#  18  pendiente                  2597 non-null   object
#  19  basural                    2597 non-null   object
#  20  torres_de_alta_tension     2597 non-null   object
#  21  linea_de_tren              2597 non-null   object
#  22  camino_de_alto_trafico     2597 non-null   object
#  23  desechos_industriales      2597 non-null   object
#  24  actividad_agropecuaria     2597 non-null   object
#  25  relleno_sanitario          2597 non-null   object
#  26  inundaciones               2597 non-null   object
#  27  jardin_de_infantes         2145 non-null   object
#  28  escuela_primaria           2142 non-null   object
#  29  escuela_secundaria         2145 non-null   object
#  30  hospital                   2141 non-null   object
#  31  sala_medica                2597 non-null   object
#  32  comisaria                  2597 non-null   object
#  33  parada_transporte_publico  2126 non-null   object
#  34  plaza                      2141 non-null   object
#  35  centro_de_deportes         2132 non-null   object
#  36  alcantarillado             2150 non-null   object
#  37  asfalto                    2141 non-null   object
#  38  alumbrado                  2153 non-null   object
#  39  recoleccion_de_residuos    2156 non-null   object
#  40  organizaciones_externas    2597 non-null   object
#  41  mayores_problemas_barrio1  2140 non-null   object
#  42  poligono                   2568 non-null   object
#  43  anio                       2597 non-null   int64
# dtypes: int64(2), object(42)
# memory usage: 892.8+ KB

# %%
df.dropna() # Elimino las filas que quedaron con valores nulos
# Out:
#              ID     provincia departamento              localidad  \
# 0     TE_000001  BUENOS AIRES        TIGRE                CHASICÓ
# 1     TE_000008       NEUQUÉN  CONFLUENCIA                NEUQUÉN
# 2     TE_000009       NEUQUÉN  CONFLUENCIA                NEUQUÉN
# 3     TE_000013       NEUQUÉN  CONFLUENCIA                NEUQUÉN
# 4     TE_000020       NEUQUÉN  CONFLUENCIA                NEUQUÉN
# ...         ...           ...          ...                    ...
# 2371  TE_004081       TUCUMÁN      CAPITAL  SAN MIGUEL DE TUCUMÁN
# 2372  TE_004082       TUCUMÁN      CAPITAL  SAN MIGUEL DE TUCUMÁN
# 2405  TE_004123       TUCUMÁN      CAPITAL  SAN MIGUEL DE TUCUMÁN
# 2406  TE_004124       TUCUMÁN      CAPITAL  SAN MIGUEL DE TUCUMÁN
# 2407  TE_004125       TUCUMÁN      CAPITAL  SAN MIGUEL DE TUCUMÁN
#
#                         nombre_barrio  \
# 0                         el ahorcado
# 1                     nueva esperanza
# 2                      loteo social 1
# 3                     toma alto godoy
# 4                        Auka Mahuida
# ...                               ...
# 2371                 nueva  esperanza
# 2372                 barrio la gaceta
# 2405                 Villa 9 de Julio
# 2406                      Canal Norte
# 2407  Ampliacion del Barrio Mataderon
#
#                                          tipo_de_barrio  cantidad_de_familias  \
# 0                                                 VILLA                   190
# 1                                          ASENTAMIENTO                    30
# 2                                          ASENTAMIENTO                    30
# 3                                          ASENTAMIENTO                    70
# 4                                          ASENTAMIENTO                   150
# ...                                                 ...                   ...
# 2371                                       ASENTAMIENTO                   250
# 2372  ASENTAMIENTO DE FORMA PLANIFICADA CON PARTICIP...                   100
# 2405                                       ASENTAMIENTO                   150
# 2406                                       ASENTAMIENTO                    30
# 2407                                       ASENTAMIENTO                   300
#
#      anio_creo_barrio                                                luz  \
# 0              1975.0  RED PÚBLICA CON MEDIDORES DOMICILIARIOS. (CADA...
# 1              1990.0  CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...
# 2              2007.0  CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...
# 3              1990.0  CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...
# 4              2004.0  CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHA...
# ...               ...                                                ...
# 2371           2012.0  RED PÚBLICA CON MEDIDORES DOMICILIARIOS. (CADA...
# 2372           1945.0  RED PÚBLICA CON MEDIDORES DOMICILIARIOS. (CADA...
# 2405           1971.0  RED PÚBLICA CON MEDIDORES DOMICILIARIOS. (CADA...
# 2406           1960.0  RED PÚBLICA CON MEDIDORES DOMICILIARIOS. (CADA...
# 2407           1980.0  RED PÚBLICA CON MEDIDORES DOMICILIARIOS. (CADA...
#
#                                                excretas  ...  \
# 0     DESAGÜE SÓLO A POZO NEGRO / CIEGO U HOYO, EXCA...  ...
# 1     RED CLOACAL PÚBLICA CONECTADA AL PLUVIAL, AL D...  ...
# 2     DESAGÜE SÓLO A POZO NEGRO / CIEGO U HOYO, EXCA...  ...
# 3                 DESAGÜE A CÁMARA SÉPTICA Y POZO CIEGO  ...
# 4                 DESAGÜE A CÁMARA SÉPTICA Y POZO CIEGO  ...
# ...                                                 ...  ...
# 2371  DESAGÜE SÓLO A POZO NEGRO / CIEGO U HOYO, EXCA...  ...
# 2372  DESAGÜE SÓLO A POZO NEGRO / CIEGO U HOYO, EXCA...  ...
# 2405              DESAGÜE A CÁMARA SÉPTICA Y POZO CIEGO  ...
# 2406              DESAGÜE A CÁMARA SÉPTICA Y POZO CIEGO  ...
# 2407  DESAGÜE SÓLO A POZO NEGRO / CIEGO U HOYO, EXCA...  ...
#
#                                 plaza               centro_de_deportes  \
# 0        A MENOS DE 10 CUADRAS (1 KM)  ENTRE 11 Y 30 CUADRAS(1 Y 3 KM)
# 1        A MENOS DE 10 CUADRAS (1 KM)  ENTRE 11 Y 30 CUADRAS(1 Y 3 KM)
# 2        A MENOS DE 10 CUADRAS (1 KM)         MÁS DE 50 CUADRAS(+5 KM)
# 3        A MENOS DE 10 CUADRAS (1 KM)  ENTRE 31 Y 50 CUADRAS(3 Y 5 KM)
# 4     ENTRE 11 Y 30 CUADRAS(1 Y 3 KM)     A MENOS DE 10 CUADRAS (1 KM)
# ...                               ...                              ...
# 2371  ENTRE 11 Y 30 CUADRAS(1 Y 3 KM)  ENTRE 11 Y 30 CUADRAS(1 Y 3 KM)
# 2372     A MENOS DE 10 CUADRAS (1 KM)         MÁS DE 50 CUADRAS(+5 KM)
# 2405     A MENOS DE 10 CUADRAS (1 KM)            NO SABE / NO RESPONDE
# 2406     A MENOS DE 10 CUADRAS (1 KM)         MÁS DE 50 CUADRAS(+5 KM)
# 2407  ENTRE 11 Y 30 CUADRAS(1 Y 3 KM)         MÁS DE 50 CUADRAS(+5 KM)
#
#      alcantarillado asfalto                     alumbrado  \
# 0                NO      NO  SI, PROVISTOS POR EL ESTADO.
# 1                NO      NO                            NO
# 2                NO      NO                            NO
# 3                NO      NO  SI, PROVISTOS POR EL ESTADO.
# 4                NO      NO                            NO
# ...             ...     ...                           ...
# 2371             NO      NO  SI, PROVISTOS POR EL ESTADO.
# 2372             NO      NO  SI, PROVISTOS POR EL ESTADO.
# 2405             NO      NO  SI, PROVISTOS POR EL ESTADO.
# 2406             NO      NO   SI, HECHOS POR LOS VECINOS.
# 2407             NO      NO                            NO
#
#                                 recoleccion_de_residuos  \
# 0     SI, DE MANERA FORMAL. (EL CAMIÓN INGRESA AL BA...
# 1                                                    NO
# 2                                                    NO
# 3     SI, DE MANERA FORMAL. (EL CAMIÓN INGRESA AL BA...
# 4                                                    NO
# ...                                                 ...
# 2371  SI, DE MANERA FORMAL. (EL CAMIÓN INGRESA AL BA...
# 2372                                                 NO
# 2405  SI, DE MANERA FORMAL. (EL CAMIÓN INGRESA AL BA...
# 2406                                                 NO
# 2407                                                 NO
#
#      organizaciones_externas        mayores_problemas_barrio1  \
# 0                         NO             DROGA/ALCOHOL/TABACO
# 1                         SÍ  FALTA DE ACCESO A LOS SERVICIOS
# 2                         NO         INSEGURIDAD/DELINCUENCIA
# 3                         NO             DROGA/ALCOHOL/TABACO
# 4                         NO                             OTRO
# ...                      ...                              ...
# 2371                      SÍ                             OTRO
# 2372                      NO         INSEGURIDAD/DELINCUENCIA
# 2405                      SÍ         INSEGURIDAD/DELINCUENCIA
# 2406                      NO         INSEGURIDAD/DELINCUENCIA
# 2407                      NO         INSEGURIDAD/DELINCUENCIA
#
#                                                poligono  anio
# 0     -58.59945100000001,-34.405688 -58.600438,-34.4...  2016
# 1     -68.09599718832222,-38.94101958422372 -68.0956...  2016
# 2     -68.11663400000001,-38.929042 -68.117119,-38.9...  2016
# 3     -68.11655008297473,-38.93412118363295 -68.1163...  2016
# 4     -68.07649248356904,-38.9414112252755 -68.07682...  2016
# ...                                                 ...   ...
# 2371  -65.22797778495792,-26.88922766953107 -65.2273...  2016
# 2372  -65.16406783921376,-26.81880324752548 -65.1641...  2016
# 2405  -65.17767910000001,-26.81221710000001 -65.1769...  2016
# 2406  -65.2108200213157,-26.79142068881948 -65.21064...  2016
# 2407  -65.17546735439314,-26.81323318156671 -65.1752...  2016
#
# [2022 rows x 44 columns]

# %%
df.isnull().sum() # Vuelvo a pasar el codigo para mostrar lo que quedo como valores nulos.
# Out:
# ID                             0
# provincia                      0
# departamento                   0
# localidad                      0
# nombre_barrio                  0
# tipo_de_barrio                 0
# cantidad_de_familias           0
# anio_creo_barrio               0
# luz                           23
# excretas                      23
# agua                           0
# energia_calefaccion          448
# energia_cocinar              454
# emergencias_policia          449
# emergencias_bomberos           0
# emergencias_ambulancia         0
# plantacion_forestal            0
# ribera_rio                     0
# pendiente                      0
# basural                        0
# torres_de_alta_tension         0
# linea_de_tren                  0
# camino_de_alto_trafico         0
# desechos_industriales          0
# actividad_agropecuaria         0
# relleno_sanitario              0
# inundaciones                   0
# jardin_de_infantes           452
# escuela_primaria             455
# escuela_secundaria           452
# hospital                     456
# sala_medica                    0
# comisaria                      0
# parada_transporte_publico    471
# plaza                        456
# centro_de_deportes           465
# alcantarillado               447
# asfalto                      456
# alumbrado                    444
# recoleccion_de_residuos      441
# organizaciones_externas        0
# mayores_problemas_barrio1    457
# poligono                      29
# anio                           0
# dtype: int64

# %%
# Para ver la cantidad de valores que podemos encontrar en una columna determinada.
df.tipo_de_barrio.value_counts()
# Out:
# ASENTAMIENTO                                                                      1703
# VILLA                                                                              773
# ASENTAMIENTO DE FORMA PLANIFICADA CON PARTICIPACIÓN DEL ESTADO (LOTEO SOCIAL).      94
# VILLA DE FORMA PLANIFICADA CON PARTICIPACIÓN DEL ESTADO (LOTEO SOCIAL).             25
# villa                                                                                1
# Asentamiento                                                                         1
# Name: tipo_de_barrio, dtype: int64

# %%
# Reemplazamos valores con texto muy largos por otros similares para simplificar el analisis
df.tipo_de_barrio = df.tipo_de_barrio.replace(["ASENTAMIENTO DE FORMA PLANIFICADA CON PARTICIPACIÓN DEL ESTADO (LOTEO SOCIAL).", "Asentamiento"], "ASENTAMIENTO")
df.tipo_de_barrio = df.tipo_de_barrio.replace(["VILLA DE FORMA PLANIFICADA CON PARTICIPACIÓN DEL ESTADO (LOTEO SOCIAL).", "villa"], "VILLA")

# %%
df.tipo_de_barrio.value_counts() # Volvemos a pasar el codigo para ver los cambios en la columna
# Out:
# ASENTAMIENTO    1798
# VILLA            799
# Name: tipo_de_barrio, dtype: int64

# %%
 # Mostrar grafico de distribución, el parametro "color" permite cambiar el color de las barras.
df['tipo_de_barrio'].hist(bins=5, color='black')
plt.title('TIPOS DE BARRIOS')
plt.grid(False)
plt.show()
plt.clf()

# %% [markdown]
# A continuación repito el procedimiento pero con las columnas "luz", "alumbrado" y "asfalto" para obtener el conteo de cuantos valores tienen.

# %%
df.luz.value_counts() # Para ver la cantidad de valores en esta columna.
# Out:
# CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHADOS A LA RED, CABLES A LOS POSTES DE LUZ DE LA CALLE, DE UNA FAMILIA A OTRA, ETC)                                   1575
# RED PÚBLICA CON MEDIDORES DOMICILIARIOS. (CADA FAMILIA CON SU FACTURA, CON SU PROPIO MEDIDOR)                                                                      798
# RED PÚBLICA CON MEDIDOR COMUNITARIO / SOCIAL. (NO HAY FACTURAS INDIVIDUALES, NO HAY UN MEDIDOR POR FAMILIA, SINO UNO O VARIOS MEDIDORES PARA MUCHAS FAMILIAS).     143
# OTRO                                                                                                                                                                51
# NO TIENE                                                                                                                                                             6
# Conexión Irregular a la Red Pública. (Enganchados a la Red, Cables a los Postes de Luz de la Calle, de una Familia a Otra, Etc)                                      1
# Name: luz, dtype: int64

# %%
# Reemplazamos valores con textos que son muy largos por otros similares pero mas acotados, para simplificar los resultados.
df.luz = df.luz.replace(["CONEXIÓN IRREGULAR A LA RED PÚBLICA. (ENGANCHADOS A LA RED, CABLES A LOS POSTES DE LUZ DE LA CALLE, DE UNA FAMILIA A OTRA, ETC)", "Conexión Irregular a la Red Pública. (Enganchados a la Red, Cables a los Postes de Luz de la Calle, de una Familia a Otra, Etc)"], "ENGANCHADOS")
df.luz = df.luz.replace(["RED PÚBLICA CON MEDIDORES DOMICILIARIOS. (CADA FAMILIA CON SU FACTURA, CON SU PROPIO MEDIDOR)", "RED PÚBLICA CON MEDIDOR COMUNITARIO / SOCIAL. (NO HAY FACTURAS INDIVIDUALES, NO HAY UN MEDIDOR POR FAMILIA, SINO UNO O VARIOS MEDIDORES PARA MUCHAS FAMILIAS)."], "RED PUBLICA")

# %%
df.luz.value_counts() # Para ver la cantidad de valores que quedaron en esta columna
# Out:
# ENGANCHADOS    1576
# RED PUBLICA     941
# OTRO             51
# NO TIENE          6
# Name: luz, dtype: int64

# %%
# Vemos graficamente su distribución, el parametro bins determina el ancho de las barras (a menor mas ancho)
df['luz'].hist(bins=7, color='black')
plt.title('CONEXION ELECTRICA')
plt.grid(False) # Si es True agrega una cuadricula al grafico, si es False queda sin cuadricula
plt.show()
plt.clf() # Se utiliza para borrar el contenido del primer gráfico antes de crear y mostrar un segundo gráfico en la misma figura.

# %%
df.alumbrado.value_counts() # Para ver la cantidad de valores en una columna determinada.
# Out:
# SI, PROVISTOS POR EL ESTADO.    1165
# NO                               648
# SI, HECHOS POR LOS VECINOS.      334
# NO SABE / NO RESPONDE              5
# Si, Provistos por el Estado.       1
# Name: alumbrado, dtype: int64

# %%
# Reemplazamos valores muy largos por otros similares para simplificar
df.alumbrado = df.alumbrado.replace(["SI, PROVISTOS POR EL ESTADO.", "SI, HECHOS POR LOS VECINOS.", "Si, Provistos por el Estado."], "SI")
df.alumbrado = df.alumbrado.replace(["NO SABE / NO RESPONDE"], "NO")

# %%
df['alumbrado'].hist(bins=5, color='black') # Vemos graficamente a su distribución del alumbrado
plt.title('ALUMBRADO PUBLICO')
plt.grid(False)
plt.show()
plt.clf()

# %%
df.alumbrado.value_counts() # Para ver la cantidad de valores en una columna determinada.
# Out:
# SI    1500
# NO     653
# Name: alumbrado, dtype: int64

# %%
df.asfalto.value_counts() # Para ver la cantidad de valores en una columna determinada.
# Out:
# NO                       1457
# SÍ                        681
# NO SABE / NO RESPONDE       2
# Si                          1
# Name: asfalto, dtype: int64

# %%
df.asfalto = df.asfalto.replace(["NO SABE / NO RESPONDE"], "NO")
df.asfalto = df.asfalto.replace(["Si"], "SÍ")

# %%
df['asfalto'].hist(bins=5, color='black') # Vemos graficamente a su distribución del asfalto
plt.title('ASFALTADO DE CALLES')
plt.grid(False)
plt.show()
plt.clf()

# %%
df.asfalto.value_counts() # Para ver la cantidad de valores en una columna determinada.
# Out:
# NO    1459
# SÍ     682
# Name: asfalto, dtype: int64

# %%
#Procedemos a analizar la informacion nuevamente

df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2597 entries, 0 to 2596
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   provincia             2597 non-null   object
#  1   tipo_de_barrio        2597 non-null   object
#  2   cantidad_de_familias  2597 non-null   int64
#  3   anio_creo_barrio      2597 non-null   object
#  4   luz                   2574 non-null   object
#  5   asfalto               2141 non-null   object
#  6   alumbrado             2153 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 142.1+ KB

# %% [markdown]
# ## Luego de procesado el dataframe continuamos aplicando predicciones

# %%
# Vamos a ver la relación entre las villas y asentamientos y sus problemas cotidianos.

# %%
#Definimos la paleta de colores que usaremos en los graficos siguientes
sns.palplot(sns.color_palette('RdBu_r'))

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = 25,7 #Tamaño del grafico
ax=sns.countplot(x="provincia", hue="alumbrado", data=df, palette='RdBu_r') #Graficar y definir el color
ax.set_xlabel("Provincias", fontsize = 15) #Texto en el eje X
ax.set_ylabel("Familias", fontsize = 15) #Texto en el eje Y
ax.set_title("Cantidad de Familias con Alumbrado por Provincias", fontsize = 20) #Texto del titulo
# Out:
# Text(0.5, 1.0, 'Cantidad de Familias con Alumbrado por Provincias')

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = 25,7
ax=sns.countplot(x="provincia", hue="asfalto", data=df, palette='RdBu_r')
ax.set_xlabel("Provincias", fontsize = 15) #Texto en el eje X
ax.set_ylabel("Familias", fontsize = 15) #Texto en el eje Y
ax.set_title("Cantidad de Familias con Asfalto por Provincias", fontsize = 20) #Texto del titulo
# Out:
# Text(0.5, 1.0, 'Cantidad de Familias con Asfalto por Provincias')

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = 25,7
ax=sns.countplot(x="provincia", hue="tipo_de_barrio", data=df, palette='RdBu_r')
ax.set_xlabel("Provincias", fontsize = 15) #Texto en el eje X
ax.set_ylabel("Familias", fontsize = 15) #Texto en el eje Y
ax.set_title("Cantidad de Familias que viven en Villa o Asentamientos, separado por Provincias", fontsize = 20) #Texto del titulo
# Out:
# Text(0.5, 1.0, 'Cantidad de Familias que viven en Villa o Asentamientos, separado por Provincias')

# %%
import urllib.request
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

import numpy as np

# %%
# Cargamos los datos y los dividimos en conjuntos para entrenar y testear.
data = df
y = data["alumbrado"]
X = data.drop(["alumbrado"], axis=1)
(X_train, X_test,
 y_train, y_test) = train_test_split(X,
                                     y,
                                     test_size=0.33,
                                     random_state=42)

# %%
# Primero creamos un arbol de decisión para ver la precisión y poder compararla
tree = DecisionTreeClassifier(max_depth=2, random_state=11) # Max depth acorta el arbol si no salia muy extenso.
tree.fit(X_train, y_train)
print(f"La precisión del Arbol de decisión es de: {tree.score(X_test, y_test)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-55019fa5485e> in <cell line: 3>()
#       1 # Primero creamos un arbol de decisión para ver la precisión y poder compararla
#       2 tree = DecisionTreeClassifier(max_depth=2, random_state=11) # Max depth acorta el arbol si no salia muy extenso.
# ----> 3 tree.fit(X_train, y_train)
#       4 print(f"La precisión del Arbol de decisión es de: {tree.score(X_test, y_test)}")
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     887         """
#     888
# --> 889         super().fit(
#     890             X,
#     891             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     184             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186             X, y = self._validate_data(
#     187                 X, y, validate_separately=(check_X_params, check_y_params)
#     188             )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     577                 if "estimator" not in check_X_params:
#     578                     check_X_params = {**default_check_params, **check_X_params}
# --> 579                 X = check_array(X, input_name="X", **check_X_params)
#     580                 if "estimator" not in check_y_params:
#     581                     check_y_params = {**default_check_params, **check_y_params}
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
# --> 879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    2068
#    2069     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070         return np.asarray(self._values, dtype=dtype)
#    2071
#    2072     def __array_wrap__(
#
# ValueError: could not convert string to float: 'BUENOS AIRES'

# %%
tree.fit(X_train, y_train)

# %%
from sklearn.tree import plot_tree # Importamos para graficar el arbol de decisión.
import matplotlib.pyplot as plt # Para manejar el tamaño del grafico del arbol.

# %%
plot_tree(decision_tree=tree, feature_names=X_train.columns, filled=True, fontsize=12);
plt.figure(figsize=(10,5))

# Feature=nombre de columnas,
# Filled=Para colorear el arbol,
# El punto y coma al final del codigo se utiliza para que no se muestre todo el texto del arbol de decision y solo muestre el grafico

# %%
# Eliminamos las demas columnas que no voy a utilizar en el analisis, lo anterior fue para practicar el manejo de los datos
df.drop("departamento", axis = 1, inplace=True)
df.drop("excretas", axis = 1, inplace=True)
df.drop("agua", axis = 1, inplace=True)
df.drop("poligono", axis = 1, inplace=True)
df.drop("anio", axis = 1, inplace=True)
df.drop("ID", axis = 1, inplace=True)
df.drop("localidad", axis = 1, inplace=True)
df.drop("energia_calefaccion", axis = 1, inplace=True)
df.drop("energia_cocinar", axis = 1, inplace=True)
df.drop("emergencias_policia", axis = 1, inplace=True)
df.drop("ribera_rio", axis = 1, inplace=True)
df.drop("pendiente", axis = 1, inplace=True)
df.drop("organizaciones_externas", axis = 1, inplace=True)
df.drop("mayores_problemas_barrio1", axis = 1, inplace=True)
df.drop("plantacion_forestal", axis = 1, inplace=True)
df.drop("emergencias_bomberos", axis = 1, inplace=True)
df.drop("emergencias_ambulancia", axis = 1, inplace=True)
df.drop("nombre_barrio", axis = 1, inplace=True)
df.drop("linea_de_tren", axis = 1, inplace=True)
df.drop("basural", axis = 1, inplace=True)
df.drop("torres_de_alta_tension", axis = 1, inplace=True)
df.drop("camino_de_alto_trafico", axis = 1, inplace=True)
df.drop("desechos_industriales", axis = 1, inplace=True)
df.drop("actividad_agropecuaria", axis = 1, inplace=True)
df.drop("relleno_sanitario", axis = 1, inplace=True)
df.drop("inundaciones", axis = 1, inplace=True)
df.drop("alcantarillado", axis = 1, inplace=True)
df.drop("recoleccion_de_residuos", axis = 1, inplace=True)
df.drop("jardin_de_infantes", axis = 1, inplace=True)
df.drop("escuela_primaria", axis = 1, inplace=True)
df.drop("escuela_secundaria", axis = 1, inplace=True)
df.drop("hospital", axis = 1, inplace=True)
df.drop("sala_medica", axis = 1, inplace=True)
df.drop("comisaria", axis = 1, inplace=True)
df.drop("parada_transporte_publico", axis = 1, inplace=True)
df.drop("plaza", axis = 1, inplace=True)
df.drop("centro_de_deportes", axis = 1, inplace=True)

df
# Las siguientes columnas contando desde la 6ta columna pertenecen a NO SÍ (ASFALTO), NO SI (ALUMBRADO), ENG|NO TIENE, ETC (LUZ)
# Out:
#                             provincia tipo_de_barrio  cantidad_de_familias  \
# 0                        BUENOS AIRES          VILLA                   190
# 1                             NEUQUÉN   ASENTAMIENTO                    30
# 2                             NEUQUÉN   ASENTAMIENTO                    30
# 3                             NEUQUÉN   ASENTAMIENTO                    70
# 4                             NEUQUÉN   ASENTAMIENTO                   150
# ...                               ...            ...                   ...
# 2592                     BUENOS AIRES   ASENTAMIENTO                    20
# 2593                     BUENOS AIRES   ASENTAMIENTO                    25
# 2594                     BUENOS AIRES   ASENTAMIENTO                    30
# 2595                     BUENOS AIRES   ASENTAMIENTO                    10
# 2596  CIUDAD AUTÓNOMA DE BUENOS AIRES          VILLA                   100
#
#      anio_creo_barrio          luz asfalto alumbrado
# 0              1975.0  RED PUBLICA      NO        SI
# 1              1990.0  ENGANCHADOS      NO        NO
# 2              2007.0  ENGANCHADOS      NO        NO
# 3              1990.0  ENGANCHADOS      NO        SI
# 4              2004.0  ENGANCHADOS      NO        NO
# ...               ...          ...     ...       ...
# 2592          No sabe  ENGANCHADOS     NaN       NaN
# 2593          No sabe  ENGANCHADOS     NaN       NaN
# 2594          No sabe  RED PUBLICA     NaN       NaN
# 2595          No sabe  ENGANCHADOS     NaN       NaN
# 2596           1999.0          NaN     NaN       NaN
#
# [2597 rows x 7 columns]
