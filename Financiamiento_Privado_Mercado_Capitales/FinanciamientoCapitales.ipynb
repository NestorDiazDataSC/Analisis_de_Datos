# %% [markdown]
# # Financiamiento Privado en Mercado de Capitales. Dólares.
# Financiamiento Privado en Mercado de Capitales por tamaño de empresa e instrumento, monto en dólares.

# %%
# Comenzamos importando las librerias a utilizar por el momento.

import numpy as np   # Importamos librerias de calculo
import pandas as pd  # Importamos librerias de uso de tablas o los dataframes
import seaborn as sns # Importamos librerias de graficos
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Direccion del dataset
#
# https://datos.gob.ar/dataset/sspm-financiamiento-privado-mercado-capitales/archivo/sspm_170.1

# %%
# Ubicar el dataset, cargarlo y mostrarlo.
url='https://raw.githubusercontent.com/NestorDiazDataSC/Analisis_de_Datos/main/Financiamiento_Privado_Mercado_Capitales/financiamiento-privado-mercado-capitales-dolares.csv'

df= pd.read_csv(url)
df
# Out:
#     indice_tiempo  financiamiento_mercado_capitales_ge_on_vcp  \
# 0      2007-01-01                                3.000000e+08
# 1      2007-02-01                                         NaN
# 2      2007-03-01                                         NaN
# 3      2007-04-01                                1.718089e+08
# 4      2007-05-01                                1.325000e+09
# ..            ...                                         ...
# 182    2022-03-01                                9.232671e+07
# 183    2022-04-01                                1.029188e+08
# 184    2022-05-01                                4.408777e+08
# 185    2022-06-01                                4.000784e+08
# 186    2022-07-01                                         NaN
#
#      financiamiento_mercado_capitales_ge_ff  \
# 0                              2.642723e+08
# 1                              1.053984e+08
# 2                              1.704575e+08
# 3                              1.197570e+08
# 4                              1.687936e+08
# ..                                      ...
# 182                            6.933919e+07
# 183                            7.868771e+07
# 184                            5.636723e+07
# 185                            1.073972e+08
# 186                                     NaN
#
#      financiamiento_mercado_capitales_ge_acciones  \
# 0                                    1.017422e+07
# 1                                    4.302251e+08
# 2                                             NaN
# 3                                    7.045493e+07
# 4                                             NaN
# ..                                            ...
# 182                                           NaN
# 183                                           NaN
# 184                                           NaN
# 185                                           NaN
# 186                                           NaN
#
#      financiamiento_mercado_capitales_ge_cdcp  \
# 0                                1.809615e+06
# 1                                1.221314e+06
# 2                                2.353346e+06
# 3                                3.086170e+06
# 4                                2.176995e+06
# ..                                        ...
# 182                                       NaN
# 183                                       NaN
# 184                                       NaN
# 185                                       NaN
# 186                                       NaN
#
#      financiamiento_mercado_capitales_ge_total  \
# 0                                 5.762561e+08
# 1                                 5.368448e+08
# 2                                 1.728108e+08
# 3                                 3.651070e+08
# 4                                 1.495971e+09
# ..                                         ...
# 182                               1.616659e+08
# 183                               1.816066e+08
# 184                               4.972449e+08
# 185                               5.074756e+08
# 186                                        NaN
#
#      financiamiento_mercado_capitales_pymes_on_vcp  \
# 0                                     2.500000e+05
# 1                                              NaN
# 2                                     3.215434e+05
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 182                                   4.134795e+06
# 183                                   1.854224e+07
# 184                                   6.854434e+06
# 185                                   3.792692e+07
# 186                                            NaN
#
#      financiamiento_mercado_capitales_pymes_ff  \
# 0                                 3.042050e+06
# 1                                 7.508643e+06
# 2                                 2.615312e+07
# 3                                 1.486692e+06
# 4                                 7.814367e+06
# ..                                         ...
# 182                               3.394862e+06
# 183                               1.371023e+07
# 184                               4.163517e+06
# 185                               4.987449e+06
# 186                                        NaN
#
#      financiamiento_mercado_capitales_pymes_acciones  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 182                                              NaN
# 183                                              NaN
# 184                                              NaN
# 185                                              NaN
# 186                                              NaN
#
#      financiamiento_mercado_capitales_pymes_cdcp  ...  \
# 0                                   1.454448e+07  ...
# 1                                   1.233830e+07  ...
# 2                                   1.546019e+07  ...
# 3                                   1.224757e+07  ...
# 4                                   1.292232e+07  ...
# ..                                           ...  ...
# 182                                          NaN  ...
# 183                                          NaN  ...
# 184                                          NaN  ...
# 185                                          NaN  ...
# 186                                          NaN  ...
#
#      manufacturas_origen_agropecuario  manufacturas_origen_industrial  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ..                                ...                             ...
# 182                               NaN                             NaN
# 183                          0.036494                        0.026766
# 184                          0.014184                             NaN
# 185                          0.014540                        0.040982
# 186                               NaN                             NaN
#
#      manufacturas_actividades_empresariales  manufacturas_papel_celulosa  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
# ..                                      ...                          ...
# 182                                     NaN                          NaN
# 183                                     NaN                          NaN
# 184                                0.001125                          NaN
# 185                                     NaN                          NaN
# 186                                     NaN                          NaN
#
#      manufacturas_servicios_informaticos  manufacturas_tecnologia  \
# 0                                    NaN                      NaN
# 1                                    NaN                      NaN
# 2                                    NaN                      NaN
# 3                                    NaN                      NaN
# 4                                    NaN                      NaN
# ..                                   ...                      ...
# 182                                  NaN                      NaN
# 183                                  NaN                      NaN
# 184                                  NaN                      NaN
# 185                                  NaN                      NaN
# 186                                  NaN                      NaN
#
#      manufacturas_telecomunicaciones  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 182                         0.459381
# 183                              NaN
# 184                              NaN
# 185                         0.009022
# 186                              NaN
#
#      manufacturas_transporte_energia_electrica  manufacturas_transporte_gas  \
# 0                                          0.0                          NaN
# 1                                          NaN                          NaN
# 2                                          NaN                          NaN
# 3                                          NaN                          NaN
# 4                                          NaN                          NaN
# ..                                         ...                          ...
# 182                                        NaN                          NaN
# 183                                        NaN                          NaN
# 184                                        NaN                          NaN
# 185                                        NaN                          NaN
# 186                                        NaN                          NaN
#
#      manufacturas_transporte_pasajeros_peajes
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 182                                       NaN
# 183                                       NaN
# 184                                       NaN
# 185                                       NaN
# 186                                       NaN
#
# [187 rows x 70 columns]
